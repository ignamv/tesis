# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[3,2,1], '.-')

# %%
plt.plot([1,2,3],[3,2,1], '-.')

# %%
import numpy as np
plt.plot(np.arange(1000), np.arange(1000), '-.')
